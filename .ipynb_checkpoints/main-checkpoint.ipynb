# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
import pickle
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('./heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
plt.pie(df['target'].value_counts(), labels=df['target'].value_counts().index, autopct='%1.1f%%')
plt.show()

# %%
cols = [col for col in df.columns if col != 'target']

fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(20, 12))
axes = axes.flatten()
for i, col in enumerate(cols):
    sns.barplot(x='target', y=col, data=df, ax=axes[i])
    axes[i].set_title(col)

for j in range(len(cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
target_corr = df.corr()['target'].sort_values(ascending=False)

print(target_corr)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %% [markdown]
# ## What Mutual Information Means
#
# ### Mutual Information measures:
# ### “How much information does this feature provide about the target?”
# ### Unlike correlation, it can detect:
#
# ### 1. nonlinear relationships
# ### 2. complex interactions
# ### 3. threshold effects

# %%
from sklearn.feature_selection import mutual_info_classif

X = df.drop('target', axis=1)
y = df['target']

mi = mutual_info_classif(X, y)

mi_scores = pd.Series(mi, index=X.columns)
print(mi_scores.sort_values(ascending=False))
# Out:
# exang       0.119825
# oldpeak     0.117960
# ca          0.109852
# thal        0.109048
# cp          0.106855
# thalach     0.075951
# chol        0.067415
# sex         0.041873
# slope       0.034166
# fbs         0.014117
# restecg     0.005522
# age         0.000000
# trestbps    0.000000
# dtype: float64

# %% [markdown]
# ## Why Standardization For Logistic Regression?
#
# ### Because Logistic Regression optimization behaves better when:
# ### 1. features are centered around 0
# ### 2. variance is similar
#
# ### Standardization helps:
# ### 1. gradient descent converge faster
# ### 2. coefficients become stable
# ### 3. regularization behave correctly

# %%
X=df.drop(columns=['target'])
y=df['target']

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, stratify=y)

# %% [markdown]
# ## Why stratify=y?
#
# ### It preserves class distribution.
#
# ### Example:
#
# ### If original dataset:
#
# ### 55% disease
# ### 45% no disease
#
# ### then both train and test maintain similar proportions

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Why NOT Fit On Test Data?
#
# ### Because test data must simulate:
#
# ### “completely unseen future data”
#
# ### If you fit scaler on test data:
#
# ### 1. model indirectly sees test distribution
# ### 2. information leaks
# ### 3. evaluation becomes unrealistic
#
# ### This is called Data Leakage. And it is one of the biggest ML mistakes.

# %%
log_model=LogisticRegression()

# %%
log_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
log_model_pred=log_model.predict(X_test_scaled)

# %%
print(classification_report(y_test, log_model_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84        28
#            1       0.82      0.97      0.89        33
#
#     accuracy                           0.87        61
#    macro avg       0.89      0.86      0.86        61
# weighted avg       0.88      0.87      0.87        61

# %%
dt_model=DecisionTreeClassifier()

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_model_pred=dt_model.predict(X_test)
print(classification_report(y_test, dt_model_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76        28
#            1       0.79      0.82      0.81        33
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.78      0.78        61
# weighted avg       0.79      0.79      0.79        61

# %%
dt_model1=DecisionTreeClassifier(max_depth=7, max_features=11)
dt_model1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=11)

# %%
dt_model1_pred=dt_model1.predict(X_test)
print(classification_report(y_test, dt_model1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83        28
#            1       0.87      0.82      0.84        33
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.84      0.84        61
# weighted avg       0.84      0.84      0.84        61

# %% [markdown]
# ### Base DT model is performing better than Hyperparameter tuned DT model. So far base DT model is performing the best

# %%
rf_model=RandomForestClassifier()
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # rf_model_pred=rf_model.predict(X_test)
# print(classification_report(y_test, rf_model_pred))

# %%
rf_model1=RandomForestClassifier(max_depth=5, max_features=11)
rf_model1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=11)

# %%
rf_model1_pred=rf_model1.predict(X_test)
print(classification_report(y_test, rf_model1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79        28
#            1       0.81      0.88      0.84        33
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.81      0.82        61
# weighted avg       0.82      0.82      0.82        61

# %%
xgb_model=XGBClassifier()
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_model_pred=xgb_model.predict(X_test)
print(classification_report(y_test, xgb_model_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        28
#            1       0.83      0.88      0.85        33
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.83      0.83        61
# weighted avg       0.84      0.84      0.84        61

# %%
xgb_model1=XGBClassifier(learning_rate=0.1, max_depth=5)

# %%
xgb_model1.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_model1_pred=xgb_model1.predict(X_test)
print(classification_report(y_test, xgb_model1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83        28
#            1       0.83      0.91      0.87        33
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61

# %% [markdown]
# ## The Base Decision Tree (DT) model performed the best in terms of evaluation metrics. The next step is deciding which metric should be prioritized: accuracy, precision, or recall.
#
# Since the dataset is fairly balanced, accuracy can still be considered a meaningful metric.
# Precision measures how many of the patients predicted as having heart disease actually have it.
# Recall measures how many of the actual heart disease cases were correctly identified by the model.
#
# In the case of heart disease prediction, both precision and recall are important:
#
# A false positive (predicting heart disease when the patient does not actually have it) may cause unnecessary stress, additional tests, and medical costs.
# A false negative (failing to identify a patient who truly has heart disease) is even more critical because the patient may not receive timely treatment.
#
# Therefore, instead of focusing only on accuracy, it is better to consider a balance between precision and recall. The F1-score is useful here because it combines both metrics into a single measure. Hence, a model with a strong F1-score along with good accuracy would be more reliable for this problem.

# %% [markdown]
# ### Now, let's compare the performance of all the models

# %%
model_performance = pd.DataFrame({
    'Model': ['Logistic Regression', 'Decision Tree', 'HP Tuned DT', 'Random Forest', 'HP Tuned RF', 'XGBoost', 'HP Tuned XGB'],
    'f1-0': [0.73, 0.79, 0.75, 0.74, 0.73, 0.75, 0.74],
    'f1-1': [0.82, 0.82, 0.72, 0.79, 0.78, 0.81, 0.79],
    'accuracy': [0.79, 0.80, 0.74, 0.77, 0.75, 0.79, 0.77]
})

# %%
model_performance
# Out:
#                  Model  f1-0  f1-1  accuracy
# 0  Logistic Regression  0.73  0.82      0.79
# 1        Decision Tree  0.79  0.82      0.80
# 2          HP Tuned DT  0.75  0.72      0.74
# 3        Random Forest  0.74  0.79      0.77
# 4          HP Tuned RF  0.73  0.78      0.75
# 5              XGBoost  0.75  0.81      0.79
# 6         HP Tuned XGB  0.74  0.79      0.77

# %% [markdown]
# ### Clearly, base Decision Tree Model is performing better than all the other models

# %%
import sys
print(sys.version)
# Out:
# 3.11.4 (main, Jul  5 2023, 08:54:11) [Clang 14.0.6 ]

# %%
# !pip --version
# Out:
# pip 26.1.1 from /Users/j/anaconda3/lib/python3.11/site-packages/pip (python 3.11)

# %%
# !pip list
# Out:
# Package                                      Version
# -------------------------------------------- -------------
# a2wsgi                                       1.10.10
# absl-py                                      1.4.0
# aiobotocore                                  2.11.1
# aiofiles                                     24.1.0
# aiohttp                                      3.9.1
# aiohttp-asgi-connector                       1.1.2
# aioitertools                                 0.7.1
# aiosignal                                    1.2.0
# aiosqlite                                    0.22.1
# alabaster                                    0.7.12
# altair                                       4.2.2
# anaconda-catalogs                            0.2.0
# anaconda-client                              1.12.0
# anaconda-navigator                           2.4.2
# anaconda-project                             0.11.1
# annotated-types                              0.6.0
# ...

# %% [markdown]
# #### pandas==2.2.3
# #### pip==26.1.1
# #### scikit-learn==1.3.0
# #### python==3.11.4

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
with open("model.pkl", "wb") as f:
    pickle.dump(dt_model, f)

# %%
with open("model.pkl", "rb") as f:
    model = pickle.load(f)

# %%
print(model.predict([[63, 1, 3, 145, 233, 1, 0, 150, 0, 2.3, 0, 0, 1]]))
# Out:
# [1]
